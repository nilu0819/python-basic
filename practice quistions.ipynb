# %%
a=[1,2,3,4,5]
a[0]
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %%
a.append(6)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
len(a)
# Out:
# 6

# %%
s={1,2,3,4}
s
# Out:
# {1, 2, 3, 4}

# %%
s.remove(3)

# %%
s
# Out:
# {1, 2, 4}

# %%
a={1,2,3}
b={3,4,5}
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
d={'name':'nilesh','age':22,'city':'surat'}
d
# Out:
# {'name': 'nilesh', 'age': 22, 'city': 'surat'}

# %%
d.values()
# Out:
# dict_values(['nilesh', 22, 'surat'])

# %%
print(d.get('age'))
# Out:
# 22

# %%
len(d)
# Out:
# 3

# %%
d['country']='india'

# %%
d
# Out:
# {'name': 'nilesh',
#  'age': 22,
#  'city': 'surat',
#  4: ('country', 'india'),
#  5: ('country', 'india'),
#  'country': 'india'}

# %%
t=('red','blue','black','green')

# %%
t
# Out:
# ('red', 'blue', 'black', 'green')

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 4

# %%
t=list(t)
print(t)
# Out:
# ['red', 'blue', 'black', 'green']

# %%
type(t)
# Out:
# list
