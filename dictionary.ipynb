# %%
tup=()

# %%
tup1=(10,20,30)

# %%
tup2=(10,77,30,66,60,89)

# %%
tup3=('one','two','three')

# %%
tup4=("nilesh",20,(50,100),(150,90))

# %%
tup5=(100,'nilesh',10.15)

# %%
tup6=('nilesh',25,[50,100],[150,90], {'nilesh','ram'},(99,22,33))
len(tup6)
# Out:
# 6

# %% [markdown]
# # tuple indexing

# %%
tup1[0]
# Out:
# 10

# %%
tup3[0][0]
# Out:
# 'o'

# %%
tup4[-1]
# Out:
# (150, 90)

# %%
tup5[-1]
# Out:
# 10.15

# %% [markdown]
# # tuple slicing

# %%
mytuple= ('one','two','three','four','five','six','seven','eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]
# Out:
# ('seven', 'eight')

# %%
mytuple[-1]
# Out:
# 'eight'

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# # remove  and change items

# %%
mytuple= ('one','two','three','four','five','six','seven','eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0]
# Out:
# 'one'

# %%
del mytuple

# %% [markdown]
# # loops through a tuple

# %%
mytuple= ('one','two','three','four','five','six','seven','eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# # count

# %%
mytuple= ('one','two','three','four','five','six','seven','eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.count('one')
# Out:
# 1

# %%
mytuple.count('eight')
# Out:
# 1

# %%
mytuple.count

# %%
dict()
# Out:
# {}

# %%
#Dictionary is a mutable data type in Python.
#A python dictionary is a collection of key and value pairs separated by a colon (:) & enclosed
#in curly braces {}.
#Keys must be unique in a dictionary, duplicate values are allowed '''

# %% [markdown]
# # creating a dictionary

# %%
dict1=dict()
dict1
# Out:
# {}

# %%
dict1={}
dict1
# Out:
# {}

# %%
dict1= {1:'one',2:'two',3:'three'}
dict1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
dict1=dict({1:'one',2:'two',3:'three'})
dict1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
dict1={'a':'one','b':'two','c':'three'}
dict1
# Out:
# {'a': 'one', 'b': 'two', 'c': 'three'}

# %%
dict1= {1:'one','b':2,3:'three'}
dict1
# Out:
# {1: 'one', 'b': 2, 3: 'three'}

# %%
dict1.keys()
# Out:
# dict_keys([1, 'b', 3])

# %%
dict1.values()
# Out:
# dict_values(['one', 2, 'three'])

# %%
dict1.items()
# Out:
# dict_items([(1, 'one'), ('b', 2), (3, 'three')])

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria']} # dictionary with
mydict
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria']}

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria'], 'B':('Bat' , 'cat')}
mydict
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria'], 'B': ('Bat', 'cat')}

# %%
mydict = {1:'one' , 2:'two' , 'A':{'Name':'asif' , 'Age' :20}, 'B':('Bat' , 'ca
mydict

# %%
keys = {'a' , 'b' , 'c' , 'd'}
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'d': None, 'c': None, 'b': None, 'a': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
value = 10
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence of
mydict3
# Out:
# {'d': 10, 'c': 10, 'b': 10, 'a': 10}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
value = [10,20,30]
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence of
mydict3
# Out:
# {'d': [10, 20, 30], 'c': [10, 20, 30], 'b': [10, 20, 30], 'a': [10, 20, 30]}

# %%
value.append(40)
mydict3
# Out:
# {'d': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40]}

# %% [markdown]
# # accesing items

# %%
mydict={1:'one',2:'two',3:'three',4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1]
# Out:
# 'one'

# %%
mydict.get(4)
# Out:
# 'four'

# %%
mydict1 = {'name':'Asif' , 'ID': 74123 , 'DOB': 1991 , 'job' :'Analyst'}
mydict1
# Out:
# {'name': 'Asif', 'ID': 74123, 'DOB': 1991, 'job': 'Analyst'}

# %%
mydict1['name']
# Out:
# 'Asif'

# %%
mydict1.get('job')
# Out:
# 'Analyst'

# %% [markdown]
# # add remove and change items

# %%
mydict1 = {'name':'asif' , 'id': 12345 , 'dob': 1991 , 'address' : 'hilsinki'}
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 1991, 'address': 'hilsinki'}

# %%
mydict1['dob']= 2002
mydict1['address']='surat'
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 2002, 'address': 'surat'}

# %%
mydict1['job'] = 'analyst'
mydict1
# Out:
# {'name': 'asif',
#  'id': 12345,
#  'dob': 2002,
#  'address': 'surat',
#  'job': 'analyst'}

# %%
mydict1.pop('job')
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 2002, 'address': 'surat'}

# %%
mydict1.popitem() # is popitem is reandomy dilite the items
# Out:
# ('address', 'surat')

# %%
del[mydict1['id']]
mydict1
# Out:
# {'name': 'asif', 'dob': 2002}

# %%
mydict1.clear()
mydict1
# Out:
# {}

# %%
del mydict1
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 del mydict1
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# # copy dictionary

# %%
mydict1 = {'name':'asif' , 'id': 12345 , 'dob': 1991 , 'address' : 'hilsinki'}
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 1991, 'address': 'hilsinki'}

# %%
mydict1 =mydict

# %%
id(mydict),id(mydict1) # id is giveing the memory address of the perticular element
# Out:
# (2144659435328, 2144659435328)

# %%
mydict2= mydict.copy()

# %%
id(mydict2)
# Out:
# 2144662327872

# %%
mydict['address']= 'surat'
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 'address': 'surat'}

# %%
mydict2
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %% [markdown]
# # loop through dictionary

# %%
mydict1 = {'name':'asif' , 'id': 12345 , 'dob': 1991 , 'address' : 'hilsinki'}
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 1991, 'address': 'hilsinki'}

# %%
mydict1['job'] = 'analyst'
mydict1
# Out:
# {'name': 'asif',
#  'id': 12345,
#  'dob': 1991,
#  'address': 'hilsinki',
#  'job': 'analyst'}

# %%
for i in mydict1:
    print(i,":",mydict1[i])
# Out:
# name : asif
# id : 12345
# dob : 1991
# address : hilsinki
# job : analyst

# %%
for i in (mydict1):
    print(mydict1[i])
# Out:
# asif
# 12345
# 1991
# hilsinki
# analyst

# %% [markdown]
# # dictionary membership

# %%
mydict1 = {'name':'asif' , 'id': 12345 , 'dob': 1991 , 'address' : 'hilsinki'}
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 1991, 'address': 'hilsinki'}

# %%
'name' in mydict1
# Out:
# True

# %%
'nilesh' in mydict1
# Out:
# False

# %%
'id' in mydict1
# Out:
# True

# %%
'address' in mydict1
# Out:
# True

# %% [markdown]
# # all / any

# %%
#True - If all all keys of the dictionary are true
#False - If any key of the dictionary is false
#The any() function returns True if any key of the dictionary is True. If not, any() returns False

# %%
mydict1 = {'name':'asif' , 'id': 12345 , 'dob': 1991 , 'address' : 'hilsinki'}
mydict1
# Out:
# {'name': 'asif', 'id': 12345, 'dob': 1991, 'address': 'hilsinki'}

# %%
all(mydict1)
# Out:
# True

# %%
any(mydict1)
# Out:
# True

# %% [markdown]
# # import math modul

# %%
x=sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x=sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
x=math.sqrt(25)
x
# Out:
# 5.0

# %%
print(math.floor(2.9)) # floor is finding the lower value
print(math.ceil(2.9))  # ceil is finding the upper value
# Out:
# 2
# 3

# %%
print(math.pow(3,2))
# Out:
# 9.0

# %%
print(math.e) # is find the apcilon value
# Out:
# 2.718281828459045

# %%
import math as m
m.sqrt(100)
# Out:
# 10.0

# %%
print(m.pi) # in this math moduls in pi value is constant
# Out:
# 3.141592653589793

# %%
from math import sqrt,pow
pow(614,5)
# Out:
# 87265354185824.0

# %% [markdown]
# # user input function in python || is command limne input

# %%
x=input()
y=input()
x=x+y
x
# Out:
#  8
#  9
# '89'

# %%
x1=input("enter a first number:")
y1=input("entre a second number:")
z=x1+y1
z
# Out:
# enter a first number: 585
# entre a second number: 58
# '58558'

# %%
x1 = input('Enter the 1st number') #whenevery you works in input function it always give you string 
a1 = int(x1)
y1 = input('Enter the 2nd number') # it dont understand as arithmetic operator
b1 = int(y1)
z1 = a1 + b1
print(z1)
# Out:
# Enter the 1st number 100
# Enter the 2nd number 8
# 108

# %%
x2 = int(input('Enter the 1st number'))
y2 = int(input('Enter the 2nd number'))
z2 = x2 + y2
z2
# Out:
# Enter the 1st number 486516
# Enter the 2nd number 18674
# 505190

# %%
ch = input('enter a char')
print(ch)
# Out:
# enter a char nilesh
# nilesh

# %%
print(ch[0])
# Out:
# n

# %%
print(ch[1])
# Out:
# i

# %%
print(ch[-1])
# Out:
# h

# %%
ch = input('enter a char')[0]
print(ch)
# Out:
# enter a char nilhf
# n

# %%
ch = input('enter a char')[2:5]
print(ch)
# Out:
# enter a char nilesh
# les

# %%
ch = input('enter a char')
print(ch) # if you enter as 2 + 6 -1 we get output as 2 + 6-1 only
# Out:
# enter a char nilesh
# nilesh

# %% [markdown]
# # eval function using input

# %%
result = eval(input('enter an expr'))
print(result)

# %%
x = 5
y = 2
print(x // y, x % y)
# Out:
# 2 1

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
v =6
v
# Out:
# 6

# %%
6 =v
# Out:
#   Cell In[18], line 1
#     6 =v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
2v =10
2v
# Out:
#   Cell In[19], line 1
#     2v =10
#     ^
# SyntaxError: invalid decimal literal

# %%
v2 =16
v2
# Out:
# 16

# %%
nit =16
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 nit =16
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 16

# %%
v@ =67
v@
# Out:
#   Cell In[23], line 1
#     v@ =67
#        ^
# SyntaxError: invalid syntax

# %%
v_=16
v_
# Out:
# 16

# %%
niT_@=89
niT_@

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
if =10
if
# Out:
#   Cell In[26], line 1
#     if =10
#        ^
# SyntaxError: invalid syntax

# %%
id (x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 id (x)
#
# NameError: name 'x' is not defined

# %%
y= 16
y
# Out:
# 16

# %%
id(y)
# Out:
# 140716521596296

# %%
age=56
print(age)
# Out:
# 56

# %%
type(age)
# Out:
# int

# %%
age= 'yt'
print(age)
# Out:
# yt

# %%
type(age)
# Out:
# str

# %%
price= 89.98
print(price)
type(price)
# Out:
# 89.98
# float

# %%
is_active=True
print(is_active)
# Out:
# True

# %%
is_active=True
print(is_active)
# Out:
# True

# %%
a=6
b=7
c=a+b
c
# Out:
# 13

# %%
type(a)
# Out:
# int

# %%
f= 2.8
f
# Out:
# 2.8

# %%
type(f)
# Out:
# float

# %%
gold =127898.00
gold
# Out:
# 127898.0

# %%
type(gold)
# Out:
# float

# %%
3e0
# Out:
# 3.0

# %%
3E1
# Out:
# 30.0

# %%
3E3
# Out:
# 3000.0

# %%
4a4 # float only e or E letter is allowed that s it
# Out:
#   Cell In[47], line 1
#     4a4 # float only e or E letter is allowed that s it
#     ^
# SyntaxError: invalid decimal literal

# %%
b = True
b
# Out:
# True

# %%
b= False
b
# Out:
# False

# %%
b2 =None
b2

# %%
True +False
# Out:
# 1

# %%
True -False
# Out:
# 1

# %%
True *False
# Out:
# 0

# %%
True /False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 True /False
#
# ZeroDivisionError: division by zero

# %%
True //False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 True //False
#
# ZeroDivisionError: integer division or modulo by zero

# %%
False / True
# Out:
# 0.0

# %%
True + False
True * False
True - True + True
# Out:
# 1

# %%
print(True + True)
print(True +False)
print(True - True)
# Out:
# 2
# 1
# 0

# %%
c =10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
print(c)
print(d)
# Out:
# (10+20j)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 print(c)
# ----> 2 print(d)
#
# NameError: name 'd' is not defined

# %% [raw]
# print(c+d)

# %%
print(c+d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(c+d)
#
# NameError: name 'd' is not defined

# %%
c2= 10
